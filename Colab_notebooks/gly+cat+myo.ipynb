# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/Internship/Kaggle'

# %% [markdown]
# # **Load Dataset**

# %%
# !kaggle datasets download -d andrewmvd/ocular-disease-recognition-odir5k
# Out:
# ...
# 100% 1.62G/1.62G [00:11<00:00, 110MB/s]
# 100% 1.62G/1.62G [00:11<00:00, 147MB/s]

# %%
# !kaggle datasets download -d jr2ngb/cataractdataset
# Out:
# ...
# 100% 3.33G/3.34G [01:29<00:00, 23.8MB/s]
# 100% 3.34G/3.34G [01:29<00:00, 39.9MB/s]

# %%
# !kaggle datasets download -d himanshuagarwal1998/glaucomadataset
# Out:
# ...
# 100% 2.53G/2.54G [01:02<00:00, 42.3MB/s]
# 100% 2.54G/2.54G [01:02<00:00, 43.5MB/s]

# %%
# !kaggle datasets download -d sovitrath/diabetic-retinopathy-224x224-2019-data
# Out:
# ...
#  97% 230M/238M [00:02<00:00, 114MB/s]
# 100% 238M/238M [00:02<00:00, 96.7MB/s]

# %%
# !kaggle datasets download -d linchundan/fundusimage1000
# Out:
# ...
#  99% 770M/778M [00:15<00:00, 13.3MB/s]
# 100% 778M/778M [00:15<00:00, 51.6MB/s]

# %%
# !unzip ocular-disease-recognition-odir5k.zip -d dataset1
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset1/preprocessed_images/2179_left.jpg
#   inflating: dataset1/preprocessed_images/2179_right.jpg
#   inflating: dataset1/preprocessed_images/217_left.jpg
#   inflating: dataset1/preprocessed_images/217_right.jpg
#   inflating: dataset1/preprocessed_images/2180_left.jpg
#   inflating: dataset1/preprocessed_images/2180_right.jpg
#   inflating: dataset1/preprocessed_images/2181_left.jpg
#   inflating: dataset1/preprocessed_images/2181_right.jpg
#   inflating: dataset1/preprocessed_images/2182_left.jpg
#   inflating: dataset1/preprocessed_images/2182_right.jpg
#   inflating: dataset1/preprocessed_images/2183_left.jpg
#   inflating: dataset1/preprocessed_images/2183_right.jpg
#   inflating: dataset1/preprocessed_images/2184_left.jpg
#   inflating: dataset1/preprocessed_images/2184_right.jpg
#   inflating: dataset1/preprocessed_images/2185_left.jpg
#   inflating: dataset1/preprocessed_images/2185_right.jpg
# ...

# %%
# !unzip cataractdataset.zip -d dataset2
# Out:
# Archive:  cataractdataset.zip
#   inflating: dataset2/README.md
#   inflating: dataset2/dataset/1_normal/NL_001.png
#   inflating: dataset2/dataset/1_normal/NL_002.png
#   inflating: dataset2/dataset/1_normal/NL_003.png
#   inflating: dataset2/dataset/1_normal/NL_004.png
#   inflating: dataset2/dataset/1_normal/NL_005.png
#   inflating: dataset2/dataset/1_normal/NL_006.png
#   inflating: dataset2/dataset/1_normal/NL_007.png
#   inflating: dataset2/dataset/1_normal/NL_008.png
#   inflating: dataset2/dataset/1_normal/NL_009.png
#   inflating: dataset2/dataset/1_normal/NL_010.png
#   inflating: dataset2/dataset/1_normal/NL_011.png
#   inflating: dataset2/dataset/1_normal/NL_012.png
#   inflating: dataset2/dataset/1_normal/NL_013.png
#   inflating: dataset2/dataset/1_normal/NL_014.png
#   inflating: dataset2/dataset/1_normal/NL_015.png
#   inflating: dataset2/dataset/1_normal/NL_016.png
#   inflating: dataset2/dataset/1_normal/NL_017.png
# ...

# %%
# !unzip diabetic-retinopathy-224x224-2019-data.zip -d dataset3

# %%
# !unzip glaucomadataset.zip -d dataset4
# Out:
# Archive:  glaucomadataset.zip
#   inflating: dataset4/Glaucoma/image100prime.tif
#   inflating: dataset4/Glaucoma/image101prime.tif
#   inflating: dataset4/Glaucoma/image102prime.tif
#   inflating: dataset4/Glaucoma/image103prime.tif
#   inflating: dataset4/Glaucoma/image104prime.tif
#   inflating: dataset4/Glaucoma/image105prime.tif
#   inflating: dataset4/Glaucoma/image106prime.tif
#   inflating: dataset4/Glaucoma/image107prime.tif
#   inflating: dataset4/Glaucoma/image108prime.tif
#   inflating: dataset4/Glaucoma/image109prime.tif
#   inflating: dataset4/Glaucoma/image10prime.jpg
#   inflating: dataset4/Glaucoma/image10prime.tif
#   inflating: dataset4/Glaucoma/image110prime.tif
#   inflating: dataset4/Glaucoma/image111prime.tif
#   inflating: dataset4/Glaucoma/image112prime.tif
#   inflating: dataset4/Glaucoma/image113prime.tif
#   inflating: dataset4/Glaucoma/image114prime.tif
#   inflating: dataset4/Glaucoma/image115prime.tif
#   inflating: dataset4/Glaucoma/image116prime.tif
# ...

# %%
# !unzip fundusimage1000.zip -d dataset5
# Out:
# Archive:  fundusimage1000.zip
#   inflating: dataset5/1000images/0.0.Normal/1ffa9627-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: dataset5/1000images/0.0.Normal/1ffa9628-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: dataset5/1000images/0.0.Normal/1ffa9629-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: dataset5/1000images/0.0.Normal/1ffa962a-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: dataset5/1000images/0.0.Normal/1ffa962b-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: dataset5/1000images/0.0.Normal/1ffa962d-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: dataset5/1000images/0.0.Normal/1ffa962e-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: dataset5/1000images/0.0.Normal/1ffa962f-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: dataset5/1000images/0.0.Normal/1ffa9630-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: dataset5/1000images/0.0.Normal/1ffa9631-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: dataset5/1000images/0.0.Normal/1ffa9632-8d87-11e8-9daf-6045cb817f5b..JPG
# ...

# %%
# !rm *.zip

# %%
import pandas as pd
df = pd.read_csv("/content/dataset1/full_df.csv")
df.head()
# Out:
#    ID  Patient Age Patient Sex  ... labels                    target     filename
# 0   0           69      Female  ...  ['N']  [1, 0, 0, 0, 0, 0, 0, 0]  0_right.jpg
# 1   1           57        Male  ...  ['N']  [1, 0, 0, 0, 0, 0, 0, 0]  1_right.jpg
# 2   2           42        Male  ...  ['D']  [0, 1, 0, 0, 0, 0, 0, 0]  2_right.jpg
# 3   4           53        Male  ...  ['D']  [0, 1, 0, 0, 0, 0, 0, 0]  4_right.jpg
# 4   5           50      Female  ...  ['D']  [0, 1, 0, 0, 0, 0, 0, 0]  5_right.jpg
#
# [5 rows x 19 columns]

# %%
df.head()
# Out:
#    ID  Patient Age Patient Sex  ... labels                    target     filename
# 0   0           69      Female  ...  ['N']  [1, 0, 0, 0, 0, 0, 0, 0]  0_right.jpg
# 1   1           57        Male  ...  ['N']  [1, 0, 0, 0, 0, 0, 0, 0]  1_right.jpg
# 2   2           42        Male  ...  ['D']  [0, 1, 0, 0, 0, 0, 0, 0]  2_right.jpg
# 3   4           53        Male  ...  ['D']  [0, 1, 0, 0, 0, 0, 0, 0]  4_right.jpg
# 4   5           50      Female  ...  ['D']  [0, 1, 0, 0, 0, 0, 0, 0]  5_right.jpg
#
# [5 rows x 19 columns]

# %%
labels = df['labels']
print(labels)
classes = set(labels)
print(classes)
# Out:
# 0       ['N']
# 1       ['N']
# 2       ['D']
# 3       ['D']
# 4       ['D']
#         ...
# 6387    ['D']
# 6388    ['D']
# 6389    ['D']
# 6390    ['D']
# 6391    ['H']
# Name: labels, Length: 6392, dtype: object
# {"['M']", "['N']", "['C']", "['D']", "['A']", "['H']", "['G']", "['O']"}

# %%
import os
def find_in_dir(index):
    path = '/content/dataset1/preprocessed_images'
    for (dirpath, dirnames, filenames) in os.walk(path):
        for filename in filenames:
            name = str(os.path.join(dirpath,filename))
            f = filename.split('_')
            if(index == f[0]):  
                return name

# %%
import shutil, os

os.mkdir('/content/dataset1/Datasets')
os.mkdir('/content/dataset1/Datasets/M')
os.mkdir('/content/dataset1/Datasets/C')
os.mkdir('/content/dataset1/Datasets/N')


for i,j in zip(df["labels"],df["filename"]):
    index = j.split("_")
    z = find_in_dir(index[0])
    if z == None :
        continue
    if i == "['C']":
        shutil.move(z, '/content/dataset1/Datasets/C')
    if i == "['N']":
        shutil.move(z, '/content/dataset1/Datasets/N')
    if i == "['M']": 
        shutil.move(z, '/content/dataset1/Datasets/M')

# %%
import os

path = '/content/dataset2/dataset/1_normal'
for (dirpath, dirnames, filenames) in os.walk(path):
    for filename in filenames:
        name = str(os.path.join(dirpath,filename))
        shutil.move(name, '/content/dataset1/Datasets/N')

# %%
import os

path = '/content/dataset2/dataset/2_cataract'
for (dirpath, dirnames, filenames) in os.walk(path):
    for filename in filenames:
        name = str(os.path.join(dirpath,filename))
        shutil.move(name, '/content/dataset1/Datasets/C')

# %%
import os

path = '/content/dataset5/1000images/9.Pathological myopia'
for (dirpath, dirnames, filenames) in os.walk(path):
    for filename in filenames:
        name = str(os.path.join(dirpath,filename))
        shutil.move(name, '/content/dataset1/Datasets/M')

# %%
import os

path = '/content/dataset5/1000images/0.0.Normal'
for (dirpath, dirnames, filenames) in os.walk(path):
    for filename in filenames:
        name = str(os.path.join(dirpath,filename))
        shutil.move(name, '/content/dataset1/Datasets/N')

# %%
os.mkdir('/content/dataset1/Datasets/G')
import os

path = '/content/dataset4/Glaucoma'
for (dirpath, dirnames, filenames) in os.walk(path):
    for filename in filenames:
        name = str(os.path.join(dirpath,filename))
        shutil.move(name, '/content/dataset1/Datasets/G')

# %%
# import os

# path = '/content/dataset4/Non Glaucoma'
# for (dirpath, dirnames, filenames) in os.walk(path):
#     for filename in filenames:
#         name = str(os.path.join(dirpath,filename))
#         shutil.move(name, '/content/dataset1/Datasets/N')

# %%
# import os

# path = '/content/dataset3/colored_images/No_DR'
# for (dirpath, dirnames, filenames) in os.walk(path):
#     for filename in filenames:
#         name = str(os.path.join(dirpath,filename))
#         shutil.move(name, '/content/dataset1/Datasets/N')

# %%
# os.mkdir('/content/dataset1/Datasets/Mild_DR')
# import os

# path = '/content/dataset3/colored_images/Mild'
# for (dirpath, dirnames, filenames) in os.walk(path):
#     for filename in filenames:
#         name = str(os.path.join(dirpath,filename))
#         shutil.move(name, '/content/dataset1/Datasets/Mild_DR')

# %%
# os.mkdir('/content/dataset1/Datasets/Moderate_DR')
# import os

# path = '/content/dataset3/colored_images/Moderate'
# for (dirpath, dirnames, filenames) in os.walk(path):
#     for filename in filenames:
#         name = str(os.path.join(dirpath,filename))
#         shutil.move(name, '/content/dataset1/Datasets/Moderate_DR')

# %%
# os.mkdir('/content/dataset1/Datasets/Severe_DR')
# import os

# path = '/content/dataset3/colored_images/Severe'
# for (dirpath, dirnames, filenames) in os.walk(path):
#     for filename in filenames:
#         name = str(os.path.join(dirpath,filename))
#         shutil.move(name, '/content/dataset1/Datasets/Severe_DR')

# %%
# os.mkdir('/content/dataset1/Datasets/Proliferate_DR')
# import os

# path = '/content/dataset3/colored_images/Proliferate_DR'
# for (dirpath, dirnames, filenames) in os.walk(path):
#     for filename in filenames:
#         name = str(os.path.join(dirpath,filename))
#         shutil.move(name, '/content/dataset1/Datasets/Proliferate_DR')

# %%
# !pip install split-folders
import splitfolders
splitfolders.ratio('/content/dataset1/Datasets', output="/content/ocular_disease_dataset_2", seed=1337, ratio=(0.8, 0.2))
# Out:
# ...
# Copying files: 4401 files [01:59, 36.71 files/s]

# %% [markdown]
# # **Images Preprocessing**

# %%
train_path = '/content/ocular_disease_dataset_2/train'
val_path = '/content/ocular_disease_dataset_2/val'

# %%
from glob import glob
folders = glob('/content/ocular_disease_dataset_2/train/*')
folders
# Out:
# ['/content/ocular_disease_dataset_2/train/M',
#  '/content/ocular_disease_dataset_2/train/G',
#  '/content/ocular_disease_dataset_2/train/N',
#  '/content/ocular_disease_dataset_2/train/C']

# %%
# import os

# folders = glob('/content/ocular_disease_dataset_2/train/N/*')
# fold_len = len(folders) // 2
# count = 0
# for i in folders:
#   os.remove(i)
#   if count == fold_len:
#     break
#   count+=1

# %%
# folders_1 = glob('/content/ocular_disease_dataset_2/train/N/*')
# len(folders_1)

# %%
# import os

# folders = glob('/content/ocular_disease_dataset_2/val/N/*')
# fold_len = len(folders) // 2
# count = 0
# for i in folders:
#   os.remove(i)
#   if count == fold_len:
#     break
#   count+=1

# %%
# folders_1 = glob('/content/ocular_disease_dataset_2/val/N/*')
# len(folders_1)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   horizontal_flip=True,
                                   rotation_range = 20)
val_datagen = ImageDataGenerator(rescale = 1./255,
                                 horizontal_flip=True,
                                 rotation_range = 20)

# %%
batch_size = 32
img_height = 224
def generate_generator_multiple(generator,dir1,batch_size, img_height,img_width):
    genX1 = generator.flow_from_directory(dir1,
                                          target_size = (img_height,img_width),
                                          class_mode = 'categorical',
                                          batch_size = batch_size,
                                          shuffle=True, 
                                          seed=7)

    while True:
            X1i = genX1.next()
            yield [X1i[0],X1i[0],X1i[0]], X1i[1] 
            
            
inputgenerator=generate_generator_multiple(train_datagen,
                                           dir1=train_path,
                                           batch_size=batch_size,
                                           img_height=img_height,
                                           img_width=img_height)       
     
testgenerator=generate_generator_multiple(val_datagen,
                                          dir1=val_path,
                                          batch_size=batch_size,
                                          img_height=img_height,
                                          img_width=img_height)

# %%
training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 shuffle = True,
                                                 class_mode = 'categorical')
# Out:
# Found 3518 images belonging to 4 classes.

# %%
val_set = val_datagen.flow_from_directory(val_path,
                                          target_size = (224, 224),
                                          batch_size = 32,
                                          shuffle = True,
                                          class_mode = 'categorical')
# Out:
# Found 883 images belonging to 4 classes.

# %%
training_set.class_indices
# Out:
# {'C': 0, 'G': 1, 'M': 2, 'N': 3}

# %% [markdown]
# # **Model Training**

# %%
from tensorflow.keras.models import load_model
model_combined = load_model('/content/drive/MyDrive/ai_healthcare/Copy of OCEn_v4_nodbts_Xcep+dense+incep.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model_combined.trainable = False

# %%
model_combined.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_8 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 230, 230, 3)  0           input_8[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# ...

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D , Flatten, MaxPooling2D
combi = model_combined.output
combi = Dense(32, activation='relu',name = 'combi1')(combi)
combi = Dense(32, activation='relu',name = 'combi2')(combi)
predictions = Dense(4, activation='softmax',name = 'combi3')(combi)
new_model = Model(inputs=model_combined.input, outputs=predictions)

# %%
new_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_8 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 230, 230, 3)  0           input_8[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# ...

# %%
from tensorflow.keras.optimizers import Adam
new_model.compile(optimizer=Adam(learning_rate = 0.001),loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf
class MyThresholdCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(MyThresholdCallback, self).__init__()
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None): 
        val_acc = logs["val_accuracy"]
        acc = logs["accuracy"]
        if val_acc >= self.threshold and acc >= val_acc:
            self.model.stop_training = True

# %%
my_callback = MyThresholdCallback(threshold=0.8)

# %%
epo = 5
r = new_model.fit(inputgenerator,
                validation_data=testgenerator,
                epochs=epo,
                steps_per_epoch=len(training_set),
                validation_steps = len(val_set))
# Out:
# Found 3518 images belonging to 4 classes.
# Epoch 1/5
# ...
# 110/110 [==============================] - 223s 2s/step - loss: 0.9010 - accuracy: 0.6694 - val_loss: 0.5573 - val_accuracy: 0.8018
# Epoch 2/5
# 110/110 [==============================] - 162s 1s/step - loss: 0.4263 - accuracy: 0.8346 - val_loss: 0.3688 - val_accuracy: 0.8664
# Epoch 3/5
# 110/110 [==============================] - 136s 1s/step - loss: 0.3503 - accuracy: 0.8650 - val_loss: 0.3432 - val_accuracy: 0.8675
# Epoch 4/5
# 110/110 [==============================] - 135s 1s/step - loss: 0.3420 - accuracy: 0.8664 - val_loss: 0.3457 - val_accuracy: 0.8607
# Epoch 5/5
# 110/110 [==============================] - 134s 1s/step - loss: 0.3403 - accuracy: 0.8673 - val_loss: 0.3461 - val_accuracy: 0.8652

# %%
# epo = 5
# r1 = new_model.fit(inputgenerator,
#                 validation_data=testgenerator,
#                 epochs=epo,
#                 steps_per_epoch=len(training_set),
#                 validation_steps = len(val_set))
# Out:
# Epoch 1/5
# 157/157 [==============================] - 154s 986ms/step - loss: 0.5770 - accuracy: 0.7877 - val_loss: 0.6956 - val_accuracy: 0.7602
# Epoch 2/5
# 157/157 [==============================] - 151s 969ms/step - loss: 0.5600 - accuracy: 0.7963 - val_loss: 0.6666 - val_accuracy: 0.7625
# Epoch 3/5
# 157/157 [==============================] - 153s 981ms/step - loss: 0.5597 - accuracy: 0.7959 - val_loss: 0.6597 - val_accuracy: 0.7713
# Epoch 4/5
# 157/157 [==============================] - 154s 984ms/step - loss: 0.5543 - accuracy: 0.7957 - val_loss: 0.6483 - val_accuracy: 0.7689
# Epoch 5/5
# 157/157 [==============================] - 152s 972ms/step - loss: 0.5537 - accuracy: 0.7999 - val_loss: 0.6620 - val_accuracy: 0.7745

# %%
new_model.save('/content/drive/MyDrive/ai_healthcare/8_class_model_ensem/8_class_OCEnsemble_no_dbts_Xcep+Inception+den201.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
import matplotlib.pyplot as plt
epochs = [i for i in range(5)]
fig , ax = plt.subplots(1,2)
train_acc = r.history['accuracy']
train_loss = r.history['loss']
val_acc = r.history['val_accuracy']
val_loss = r.history['val_loss']
fig.set_size_inches(16,9)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Testing Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Testing Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")

plt.show()

# %%
# import matplotlib.pyplot as plt
# epochs = [i for i in range(10)]
# fig , ax = plt.subplots(1,2)
# train_acc = r.history['accuracy'] + r1.history['accuracy']
# train_loss = r.history['loss']+r1.history['loss']
# val_acc = r.history['val_accuracy']+r1.history['val_accuracy']
# val_loss = r.history['val_loss']+r1.history['val_loss']
# fig.set_size_inches(16,9)

# ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
# ax[0].plot(epochs , val_acc , 'ro-' , label = 'Testing Accuracy')
# ax[0].set_title('Training & Validation Accuracy')
# ax[0].legend()
# ax[0].set_xlabel("Epochs")
# ax[0].set_ylabel("Accuracy")

# ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
# ax[1].plot(epochs , val_loss , 'r-o' , label = 'Testing Loss')
# ax[1].set_title('Testing Accuracy & Loss')
# ax[1].legend()
# ax[1].set_xlabel("Epochs")
# ax[1].set_ylabel("Loss")

# plt.show()

# %% [markdown]
# # **Results**

# %%
batch_size = 32
img_height = 224
def generate_generator_multiple(generator,dir1,batch_size, img_height,img_width):
    genX1 = generator.flow_from_directory(dir1,
                                          target_size = (img_height,img_width),
                                          class_mode = 'categorical',
                                          batch_size = batch_size,
                                          shuffle=False, 
                                          seed=7)

    while True:
            X1i = genX1.next()
            yield [X1i[0],X1i[0],X1i[0]], X1i[1] 
            
            
inputgenerator_eval=generate_generator_multiple(train_datagen,
                                           dir1=train_path,
                                           batch_size=batch_size,
                                           img_height=img_height,
                                           img_width=img_height)       
     
testgenerator_eval=generate_generator_multiple(val_datagen,
                                          dir1=val_path,
                                          batch_size=batch_size,
                                          img_height=img_height,
                                          img_width=img_height)

# %%
import numpy as np
Y_pred = new_model.predict_generator(testgenerator_eval, len(val_set.classes)//val_set.batch_size +1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# Found 883 images belonging to 4 classes.

# %%
y_pred = np.argmax(Y_pred, axis=1)

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
print('Confusion Matrix')
cf = confusion_matrix(val_set.classes, y_pred)
print(cf)
# Out:
# Confusion Matrix
# [[ 59   2   0  18]
#  [  0  66   0  37]
#  [  0   0  50   8]
#  [ 16  28   6 593]]

# %%
print('Classification Report')
target_names = ['C','G','M','N']
print(classification_report(val_set.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            C       0.79      0.75      0.77        79
#            G       0.69      0.64      0.66       103
#            M       0.89      0.86      0.88        58
#            N       0.90      0.92      0.91       643
#
#     accuracy                           0.87       883
#    macro avg       0.82      0.79      0.80       883
# weighted avg       0.87      0.87      0.87       883

# %%
import seaborn as sns
sns.heatmap(cf,annot=True)
