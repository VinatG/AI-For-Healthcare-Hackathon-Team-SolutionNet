# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout,Flatten,Conv2D,MaxPooling2D
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model

# %% [markdown]
# Model 1,2 and 3 use Xception for feature extraction

# %%
from tensorflow.keras.applications  import Xception
modelX = Xception(input_shape=(224,224,3),weights='imagenet', include_top=False)
modelX.trainable = False

# %% [markdown]
# Myopia model

# %%
model1 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/Myopia_Xception.h5')

# %%
model1.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 111, 111, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 111, 111, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 111, 111, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# Cataract model

# %%
model2 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/Cataract model_xception.h5')

# %%
model2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 111, 111, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 111, 111, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# Glycoma model

# %%
model3 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/glaucoma_model_xception_224.h5')

# %%
model3.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 111, 111, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 111, 111, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# Diabetes model (vgg 19)

# %%
model4 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/Diabetes_vgg16.h5')
model4.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %% [markdown]
# Freezing the layers

# %%
inf = 0
for layer in model4.layers:
    # make not trainable
    layer.trainable = False
    # rename to avoid 'unique layer name' issue
    layer._name = 'vgg_' + str(inf+1) + '_' + layer.name
    inf += 1

# %% [markdown]
# Getting classification layers from Model 1,2 and 3

# %%
model5 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/Glaucoma densenet201_224.h5')
model5.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# ...

# %%
model6 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/Cataract model_densenet201.h5')
model6.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 230, 230, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# ...

# %%
model7 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/Myopia densenet201.h5')
model7.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# ...

# %%
model8 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/Diabetes_vgg19.h5')
model8.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...

# %%
inf = 0
for layer in model8.layers:
    # make not trainable
    layer.trainable = False
    # rename to avoid 'unique layer name' issue
    layer._name = 'vgg19_' + str(inf+1) + '_' + layer.name
    inf += 1

# %%
from tensorflow.keras.applications  import InceptionV3
modelI = InceptionV3(input_shape=(224,224,3),weights='imagenet', include_top=False)
modelI.trainable = False

# %%
# dlayer11 = model1.get_layer(index= -5)
dlayer12 = model1.get_layer(index= -4)
dlayer13 = model1.get_layer(index= -3)
dlayer14 = model1.get_layer(index= -2)
dlayer15 = model1.get_layer(index= -1)

# %%
dlayer20 = model2.get_layer(index= -4)
dlayer21 = model2.get_layer(index= -3)
dlayer22 = model2.get_layer(index= -2)
dlayer23 = model2.get_layer(index= -1)

# %%
dlayer30 = model3.get_layer(index= -4)
dlayer31 = model3.get_layer(index= -3)
dlayer32 = model3.get_layer(index= -2)
dlayer33 = model3.get_layer(index= -1)

# %%
# dlayer50 = model5.get_layer(index= -5)
dlayer51 = model5.get_layer(index= -4)
dlayer52 = model5.get_layer(index= -3)
dlayer53 = model5.get_layer(index= -2)
dlayer54 = model5.get_layer(index= -1)

# %%
dlayer60 = model6.get_layer(index= -4)
dlayer61 = model6.get_layer(index= -3)
dlayer62 = model6.get_layer(index= -2)
dlayer63 = model6.get_layer(index= -1)

# %%
dlayer70 = model7.get_layer(index= -4)
dlayer71 = model7.get_layer(index= -3)
dlayer72 = model7.get_layer(index= -2)
dlayer73 = model7.get_layer(index= -1)

# %%
modeln = modelX.output
common = GlobalAveragePooling2D()(modeln)

# %%
modelm = modelD.output
common2 = GlobalAveragePooling2D()(modelm)

# %% [markdown]
# Combining classifiers of all models

# %%
# combi1 = dlayer11(common)
combi1 = dlayer12(common)
combi1 = dlayer13(combi1)
combi1 = dlayer14(combi1)
combi1 = dlayer15(combi1)

# %%
combi2 = dlayer20(common)
combi2 = dlayer21(combi2)
combi2 = dlayer22(combi2)
combi2 = dlayer23(combi2)

# %%
combi3 = dlayer30(common)
combi3 = dlayer31(combi3)
combi3 = dlayer32(combi3)
combi3 = dlayer33(combi3)

# %%
# combi5 = dlayer50(common2)
combi5 = dlayer51(common2)
combi5 = dlayer52(combi5)
combi5 = dlayer53(combi5)
combi5 = dlayer54(combi5)

# %%
combi6 = dlayer60(common2)
combi6 = dlayer61(combi6)
combi6 = dlayer62(combi6)
combi6 = dlayer63(combi6)

# %%
combi7 = dlayer70(common2)
combi7 = dlayer71(combi7)
combi7 = dlayer72(combi7)
combi7 = dlayer73(combi7)

# %%
dlayer30._name = 'dlayer30'
dlayer31._name = 'dlayer31'
dlayer32._name = 'dlayer32'
dlayer33._name = 'dlayer33'

# %%
# dlayer50._name = 'dlayer50'
dlayer51._name = 'dlayer91'
dlayer52._name = 'dlayer92'
dlayer53._name = 'dlayer93'
dlayer54._name = 'dlayer94'

# %%
dlayer70._name = 'dlayer100'
dlayer71._name = 'dlayer101'
dlayer72._name = 'dlayer102'
dlayer73._name = 'dlayer103'

# %%
from tensorflow.keras.layers import concatenate
modeln = concatenate([combi3,combi2,combi1,model4.output,combi5,combi6,combi7,model8.output])

# %% [markdown]
# New model that classifies all diseases

# %%
modelend = Model(inputs=[modelX.input,model4.input,modelI.input,model8.input], outputs=modeln)

# %%
modelend.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 111, 111, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 111, 111, 32) 96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 111, 111, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# ...

# %%
modelend.save('/content/gdrive/MyDrive/Ocular/OCEnsemble_v2_Xcep+Incpv3.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
tf.keras.utils.plot_model(modelend,to_file= 'modelcobi.png')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
modelfin = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/OCEnsemble_v2_Xcep+Incpv3.h5')
modelfin.summary()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 111, 111, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 111, 111, 32) 96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 111, 111, 32) 0           batch_normalization_4[0][0]
# ...

# %%
from tensorflow.keras.applications  import DenseNet201
modelD = DenseNet201(input_shape=(224,224,3),weights='imagenet', include_top=False)
modelD.trainable = False

# %%
from tensorflow.keras.layers import concatenate
modelout = concatenate([modelfin.output,combi5,combi6,combi7])

# %%
modelfinal = Model(inputs=[modelfin.input,modelI.input], outputs=modelout)

# %%
tf.keras.utils.plot_model(modelfinal,to_file= 'modelcbobi.png')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
modelfinal.save('/content/gdrive/MyDrive/Ocular/OCEnsemble_v3_Xcep+Incpv3+dense.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
model9 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/glaucoma_inception.h5')
# model9.summary()

# %%
model10 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/Cataract_model_inceptionv3.h5')

# %%
model11 = tf.keras.models.load_model('/content/gdrive/MyDrive/Ocular/myopia_model_InceptionV3.h5')

# %%
dlayer91 = model9.get_layer(index= -4)
dlayer92 = model9.get_layer(index= -3)
dlayer93 = model9.get_layer(index= -2)
dlayer94 = model9.get_layer(index= -1)

# %%
dlayer101 = model10.get_layer(index= -4)
dlayer102 = model10.get_layer(index= -3)
dlayer103 = model10.get_layer(index= -2)
dlayer104 = model10.get_layer(index= -1)

# %%
dlayer111 = model11.get_layer(index= -4)
dlayer112 = model11.get_layer(index= -3)
dlayer113 = model11.get_layer(index= -2)
dlayer114 = model11.get_layer(index= -1)

# %%
modelo = modelI.output
common3 = GlobalAveragePooling2D()(modelo)

# %%
combi9 = dlayer91(common3)
combi9 = dlayer92(combi9)
combi9 = dlayer93(combi9)
combi9 = dlayer94(combi9)

# %%
combi10 = dlayer101(common3)
combi10 = dlayer102(combi10)
combi10 = dlayer103(combi10)
combi10 = dlayer104(combi10)

# %%
combi11 = dlayer111(common3)
combi11 = dlayer112(combi11)
combi11 = dlayer113(combi11)
combi11 = dlayer114(combi11)

# %%
dlayer111._name = 'dlayer110'
dlayer112._name = 'dlayer111'
dlayer113._name = 'dlayer112'
dlayer114._name = 'dlayer113'

# %%
modelout = concatenate([combi3,combi2,combi1,combi5,combi6,combi7,combi9,combi10,combi11])

# %%
modelfinal2 = Model(inputs=[modelX.input,modelD.input,modelI.input], outputs=modelout)

# %%
modelfinal2.save('/content/gdrive/MyDrive/Ocular/OCEn_v4_nodbts_Xcep+dense+incep.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
